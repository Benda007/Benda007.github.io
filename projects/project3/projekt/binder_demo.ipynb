# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🏥 Project 3: Insurance Agent - CLI Demo\n",
    "\n",
    "Insurance records management system using CSV storage."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import os\n",
    "os.chdir('projects/project3/projekt')\n",
    "print(\"📂 Current directory:\", os.getcwd())\n",
    "print(\"📄 Files:\", os.listdir('.'))"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 🚀 Run the Application"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "!python main.py"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 📋 View CSV Database"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import csv\n",
    "\n",
    "try:\n",
    "    with open('testovaci_databaze.csv', 'r', encoding='utf-8') as f:\n",
    "        reader = csv.reader(f)\n",
    "        print(\"Current database records:\\n\")\n",
    "        for i, row in enumerate(reader, 1):\n",
    "            print(f\"{i}. {row}\")\n",
    "except FileNotFoundError:\n",
    "    print(\"No database file found. Run the application to create it!\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 💡 Full Terminal Access\n",
    "\n",
    "**File → New → Terminal**, then:\n",
    "```bash\n",
    "cd projects/project3/projekt\n",
    "python main.py\n",
    "```"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
