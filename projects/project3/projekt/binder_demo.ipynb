# %% [markdown]
# # 🏥 Project 3: Insurance Agent - CLI Demo
#
# Insurance records management system using CSV storage.
#
# ## 🎯 Features
# - Add, edit, and delete insured persons
# - Search by name or other criteria
# - CSV-based persistent storage
# - Pure Python - no external dependencies!
#
# ---

# %% [markdown]
# ## 🚀 Setup Environment

# %%
import os

# Navigate to project directory
os.chdir('projects/project3/projekt')
print("📂 Current directory:", os.getcwd())
print("📄 Project files:")
for f in os.listdir('.'):
    if not f.startswith('__'):
        print(f"  • {f}")

# %% [markdown]
# ## 📋 View CSV Database
#
# Let's examine the current insurance database:

# %%
import csv

try:
    with open('testovaci_databaze.csv', 'r', encoding='utf-8') as f:
        reader = csv.reader(f)
        print("📊 Current Insurance Records:\n")
        for i, row in enumerate(reader, 1):
            print(f"{i}. {' | '.join(row)}")
except FileNotFoundError:
    print("⚠️ No database file found yet.")
    print("Run the application to create it!")

# %% [markdown]
# ## 🚀 Run the Application
#
# **Interactive CLI Application**
#
# This will start the insurance management system with a menu interface.
#
# **⚠️ Note:** Interactive menus work best in a terminal. See instructions below for full terminal access.

# %%
# Run the main application
# !python main.py

# %% [markdown]
# ## 🔍 Inspect the Code Structure

# %%
# Show available modules
print("📦 Project Modules:\n")

# Check main.py
print("1️⃣ main.py - Main application entry point")
with open('main.py', 'r', encoding='utf-8') as f:
    lines = f.readlines()[:10]
    print("   First 10 lines:")
    for line in lines:
        print(f"   {line.rstrip()}")

print("\n2️⃣ insured.py - InsuredPerson class")
print("3️⃣ insurance_agent.py - InsuranceAgent class")

# %% [markdown]
# ## 📊 Database Statistics

# %%
import csv

try:
    with open('testovaci_databaze.csv', 'r', encoding='utf-8') as f:
        reader = csv.reader(f)
        records = list(reader)
        
    print("📈 Database Statistics:")
    print(f"\n📋 Total records: {len(records)}")
    
    if len(records) > 0:
        print(f"📝 Fields per record: {len(records[0])}")
        print(f"\n🔝 Sample record:")
        if len(records) > 0:
            print(f"   {records[0]}")
            
except FileNotFoundError:
    print("No database file exists yet.")

# %% [markdown]
# ## 💡 For Full Interactive Experience
#
# Jupyter notebooks have limited support for interactive CLI menus. For the **best experience**:
#
# ### Terminal Access (Recommended)
# 1. **File → New → Terminal** (in the top menu)
# 2. Navigate to project:
#    ```bash
#    cd projects/project3/projekt
#    ```
# 3. Run the application:
#    ```bash
#    python main.py
#    ```
#
# This gives you full interactive menu access with all features:
# - Add new insured persons
# - Search and filter records
# - Edit existing records
# - Delete records
# - View all records in formatted tables

# %% [markdown]
# ## 📚 Technical Details
#
# ### Technologies Used:
# - **Python 3.12** - Core programming language
# - **CSV module** - Data persistence (standard library)
# - **re module** - Input validation (standard library)
#
# ### Architecture:
# - **Object-oriented design**:
#   - `InsuredPerson` - Data model for individual records
#   - `InsuranceAgent` - Business logic and data management
#   - `main.py` - CLI interface and menu system
# - **CSV-based storage** - Simple, portable data format
# - **No external dependencies** - Uses only Python standard library
#
# ### Features:
# ✅ Full CRUD operations (Create, Read, Update, Delete)
# ✅ Search and filter functionality
# ✅ Input validation with regex
# ✅ Formatted table output
# ✅ Persistent CSV storage
# ✅ User-friendly CLI menu
#
# ---
#
# ### 💻 View Source Code:
# **GitHub Repository:** [Benda007.github.io](https://github.com/Benda007/Benda007.github.io)
#
# **Project Location:** `projects/project3/projekt/`
#
# ---
#
# *This demo runs in a temporary Binder environment. Changes to the CSV file will not persist after the session ends.*
