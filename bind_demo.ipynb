# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": 'null',
   "id": "d67ba8aa",
   "metadata": {},
   "outputs": [],
   "source": [
    "{\n",
    " \"cells\": [\n",
    "  {\n",
    "   \"cell_type\": \"markdown\",\n",
    "   \"metadata\": {},\n",
    "   \"source\": [\n",
    "    \"# 🚀 Portfolio Projects - CLI Demos\\n\",\n",
    "    \"\\n\",\n",
    "    \"Welcome! Try my command-line applications in this interactive environment.\\n\",\n",
    "    \"\\n\",\n",
    "    \"---\\n\",\n",
    "    \"\\n\",\n",
    "    \"## 📂 Available Projects\\n\",\n",
    "    \"\\n\",\n",
    "    \"### [🧠 Project 2: Headache Tracker →](projects/project2/binder_demo.ipynb)\\n\",\n",
    "    \"Track and analyze headache patterns with SQLite database.\\n\",\n",
    "    \"- Interactive CLI for adding/filtering records\\n\",\n",
    "    \"- Excel export/import\\n\",\n",
    "    \"- Medication effectiveness tracking\\n\",\n",
    "    \"\\n\",\n",
    "    \"### [🏥 Project 3: Insurance Agent →](projects/project3/projekt/binder_demo.ipynb)\\n\",\n",
    "    \"Manage insurance records with CSV storage.\\n\",\n",
    "    \"- Pure Python (no dependencies)\\n\",\n",
    "    \"- CSV-based persistence\\n\",\n",
    "    \"- Search and filter capabilities\\n\",\n",
    "    \"\\n\",\n",
    "    \"### [☕ Project 4: Coffee Shop Database →](projects/project4/binder_demo.ipynb)\\n\",\n",
    "    \"Explore coffee shop data with SQL queries.\\n\",\n",
    "    \"- SQLite database\\n\",\n",
    "    \"- Pre-written query examples\\n\",\n",
    "    \"- Interactive SQL terminal\\n\",\n",
    "    \"\\n\",\n",
    "    \"---\\n\",\n",
    "    \"\\n\",\n",
    "    \"## 🖥️ Terminal Access\\n\",\n",
    "    \"\\n\",\n",
    "    \"For full CLI experience: **File → New → Terminal**\\n\",\n",
    "    \"\\n\",\n",
    "    \"Then navigate to any project:\\n\",\n",
    "    \"```bash\\n\",\n",
    "    \"cd projects/project2\\n\",\n",
    "    \"python project.py --help\\n\",\n",
    "    \"```\\n\",\n",
    "    \"\\n\",\n",
    "    \"---\\n\",\n",
    "    \"\\n\",\n",
    "    \"**GitHub:** [View source code →](https://github.com/Benda007/Benda007.github.io.git)\"\n",
    "   ]\n",
    "  }\n",
    " ],\n",
    " \"metadata\": {\n",
    "  \"kernelspec\": {\n",
    "   \"display_name\": \"Python 3\",\n",
    "   \"language\": \"python\",\n",
    "   \"name\": \"python3\"\n",
    "  }\n",
    " },\n",
    " \"nbformat\": 4,\n",
    " \"nbformat_minor\": 4\n",
    "}"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'code',
#    'execution_count': 'null',
#    'id': 'd67ba8aa',
#    'metadata': {},
#    'outputs': [],
#    'source': ['{\n',
#     ' "cells": [\n',
#     '  {\n',
#     '   "cell_type": "markdown",\n',
#     '   "metadata": {},\n',
#     '   "source": [\n',
#     '    "# 🚀 Portfolio Projects - CLI Demos\\n",\n',
#     '    "\\n",\n',
#     '    "Welcome! Try my command-line applications in this interactive environment.\\n",\n',
#     '    "\\n",\n',
#     '    "---\\n",\n',
#     '    "\\n",\n',
#     '    "## 📂 Available Projects\\n",\n',
#     '    "\\n",\n',
#     '    "### [🧠 Project 2: Headache Tracker →](projects/project2/binder_demo.ipynb)\\n",\n',
#     '    "Track and analyze headache patterns with SQLite database.\\n",\n',
#     '    "- Interactive CLI for adding/filtering records\\n",\n',
#     '    "- Excel export/import\\n",\n',
#     '    "- Medication effectiveness tracking\\n",\n',
#     '    "\\n",\n',
# ...
